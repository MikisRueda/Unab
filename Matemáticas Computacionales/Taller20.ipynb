# %% [markdown]
# <a href="https://colab.research.google.com/github/MikisRueda/MC-2023-Miguel-Rueda/blob/main/Taller20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de entrada
X = np.array([0, 1, 2, 3, 4, 5, 6])
Y = np.array([4.2, 1.4, 0, -0.4, -0.1, 1.6, 4.1])

# Ajuste del polinomio de segundo grado
coefficients = np.polyfit(X, Y, 2)
p = np.poly1d(coefficients)

# Cálculo del coeficiente de correlación
r = np.corrcoef(X, Y)[0,1]

# Graficar la curva
plt.scatter(X, Y)
x = np.linspace(np.min(X), np.max(X), 100)
plt.plot(x, p(x), 'r')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Ajuste del polinomio de segundo grado')
plt.text(1, 8, 'r = {:.2f}'.format(r))
plt.show()
